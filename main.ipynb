# %%
import pandas as pd

data = pd.read_csv('rainfall.csv')
data
# Out:
#                     SUBDIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN
# 0     ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1  29.2    2.3  528.8  517.5  \
# 1     ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8  12.2    0.0  446.1  537.1
# 2     ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0   0.0    1.0  235.1  479.9
# 3     ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7   0.0  202.4  304.5  495.1
# 4     ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0   3.3   26.9  279.5  628.7
# ...                         ...   ...   ...    ...   ...    ...    ...    ...
# 4111                LAKSHADWEEP  2011   5.1    2.8   3.1   85.9  107.2  153.6
# 4112                LAKSHADWEEP  2012  19.2    0.1   1.6   76.8   21.2  327.0
# 4113                LAKSHADWEEP  2013  26.2   34.4  37.5    5.3   88.3  426.2
# 4114                LAKSHADWEEP  2014  53.2   16.1   4.4   14.9   57.4  244.1
# 4115                LAKSHADWEEP  2015   2.2    0.5   3.7   87.1  133.1  296.6
#
# ...

# %%
data.head()
# Out:
#                  SUBDIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN
# 0  ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1  29.2    2.3  528.8  517.5  \
# 1  ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8  12.2    0.0  446.1  537.1
# 2  ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0   0.0    1.0  235.1  479.9
# 3  ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7   0.0  202.4  304.5  495.1
# 4  ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0   3.3   26.9  279.5  628.7
#
#      JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  Jan-Feb  Mar-May
# 0  365.1  481.1  332.6  388.5  558.2   33.6  3373.2    136.3    560.3  \
# 1  228.9  753.7  666.2  197.2  359.0  160.5  3520.7    159.8    458.3
# 2  728.4  326.7  339.0  181.2  284.4  225.0  2957.4    156.7    236.1
# 3  502.0  160.1  820.4  222.2  308.7   40.1  3079.6     24.1    506.9
# 4  368.7  330.5  297.0  260.7   25.4  344.7  2566.7      1.3    309.7
#
#    Jun-Sep  Oct-Dec
# 0   1696.3    980.3
# 1   2185.9    716.7
# 2   1874.0    690.6
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4116 entries, 0 to 4115
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   SUBDIVISION  4116 non-null   object
#  1   YEAR         4116 non-null   int64
#  2   JAN          4112 non-null   float64
#  3   FEB          4113 non-null   float64
#  4   MAR          4110 non-null   float64
#  5   APR          4112 non-null   float64
#  6   MAY          4113 non-null   float64
#  7   JUN          4111 non-null   float64
#  8   JUL          4109 non-null   float64
#  9   AUG          4112 non-null   float64
#  10  SEP          4110 non-null   float64
#  11  OCT          4109 non-null   float64
#  12  NOV          4105 non-null   float64
#  13  DEC          4106 non-null   float64
#  14  ANNUAL       4090 non-null   float64
#  15  Jan-Feb      4110 non-null   float64
#  16  Mar-May      4107 non-null   float64
#  17  Jun-Sep      4106 non-null   float64
# ...

# %% [markdown]
# # EDA (Exploratory Data Analysis)

# %%
data.isnull().sum()
# Out:
# SUBDIVISION     0
# YEAR            0
# JAN             4
# FEB             3
# MAR             6
# APR             4
# MAY             3
# JUN             5
# JUL             7
# AUG             4
# SEP             6
# OCT             7
# NOV            11
# DEC            10
# ANNUAL         26
# Jan-Feb         6
# Mar-May         9
# Jun-Sep        10
# Oct-Dec        13
# dtype: int64

# %%
data['SUBDIVISION'].value_counts()
# Out:
# SUBDIVISION
# WEST MADHYA PRADESH                   115
# EAST RAJASTHAN                        115
# COASTAL KARNATAKA                     115
# TAMIL NADU                            115
# RAYALSEEMA                            115
# TELANGANA                             115
# COASTAL ANDHRA PRADESH                115
# CHHATTISGARH                          115
# VIDARBHA                              115
# MATATHWADA                            115
# MADHYA MAHARASHTRA                    115
# KONKAN & GOA                          115
# SAURASHTRA & KUTCH                    115
# GUJARAT REGION                        115
# EAST MADHYA PRADESH                   115
# KERALA                                115
# WEST RAJASTHAN                        115
# SOUTH INTERIOR KARNATAKA              115
# JAMMU & KASHMIR                       115
# HIMACHAL PRADESH                      115
# PUNJAB                                115
# HARYANA DELHI & CHANDIGARH            115
# ...

# %%
data.duplicated().sum()
# Out:
# 0

# %%
numeric_data = data.drop(columns=['SUBDIVISION'])  
mean_values = numeric_data.mean()

# %%
print(mean_values)
# Out:
# YEAR       1958.218659
# JAN          18.957320
# FEB          21.805325
# MAR          27.359197
# APR          43.127432
# MAY          85.745417
# JUN         230.234444
# JUL         347.214334
# AUG         290.263497
# SEP         197.361922
# OCT          95.507009
# NOV          39.866163
# DEC          18.870580
# ANNUAL     1411.008900
# Jan-Feb      40.747786
# Mar-May     155.901753
# Jun-Sep    1064.724769
# Oct-Dec     154.100487
# dtype: float64

# %%
numeric_data = numeric_data.fillna(numeric_data.mean())

# %%
numeric_data.head()
numeric_data.isnull().sum()
numeric_data.isnull().any()
# Out:
# YEAR       False
# JAN        False
# FEB        False
# MAR        False
# APR        False
# MAY        False
# JUN        False
# JUL        False
# AUG        False
# SEP        False
# OCT        False
# NOV        False
# DEC        False
# ANNUAL     False
# Jan-Feb    False
# Mar-May    False
# Jun-Sep    False
# Oct-Dec    False
# dtype: bool

# %%
data_without_null = data.dropna()

numeric_data = data_without_null.drop(columns=['SUBDIVISION'])

mean_values = numeric_data.mean()

numeric_data_filled = numeric_data.fillna(mean_values)

numeric_data_filled['SUBDIVISION'] = data_without_null['SUBDIVISION']

# %%
data_without_null.isnull().sum()
# Out:
# SUBDIVISION    0
# YEAR           0
# JAN            0
# FEB            0
# MAR            0
# APR            0
# MAY            0
# JUN            0
# JUL            0
# AUG            0
# SEP            0
# OCT            0
# NOV            0
# DEC            0
# ANNUAL         0
# Jan-Feb        0
# Mar-May        0
# Jun-Sep        0
# Oct-Dec        0
# dtype: int64

# %%
data_without_null.head()
# Out:
#                  SUBDIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN
# 0  ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1  29.2    2.3  528.8  517.5  \
# 1  ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8  12.2    0.0  446.1  537.1
# 2  ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0   0.0    1.0  235.1  479.9
# 3  ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7   0.0  202.4  304.5  495.1
# 4  ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0   3.3   26.9  279.5  628.7
#
#      JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  Jan-Feb  Mar-May
# 0  365.1  481.1  332.6  388.5  558.2   33.6  3373.2    136.3    560.3  \
# 1  228.9  753.7  666.2  197.2  359.0  160.5  3520.7    159.8    458.3
# 2  728.4  326.7  339.0  181.2  284.4  225.0  2957.4    156.7    236.1
# 3  502.0  160.1  820.4  222.2  308.7   40.1  3079.6     24.1    506.9
# 4  368.7  330.5  297.0  260.7   25.4  344.7  2566.7      1.3    309.7
#
#    Jun-Sep  Oct-Dec
# 0   1696.3    980.3
# 1   2185.9    716.7
# 2   1874.0    690.6
# ...

# %%
data_without_null.to_csv("data_without_null", index=False)

# %%
data_without_null.YEAR.unique()
# Out:
# array([1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1910, 1911, 1912,
#        1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1925,
#        1926, 1927, 1928, 1929, 1930, 1931, 1933, 1934, 1935, 1937, 1938,
#        1939, 1940, 1941, 1946, 1949, 1950, 1951, 1952, 1953, 1954, 1955,
#        1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966,
#        1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977,
#        1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988,
#        1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999,
#        2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010,
#        2011, 2012, 2013, 2014, 2015, 1923, 1924, 1932, 1936, 1942, 1943,
#        1944, 1945, 1947, 1948, 1909], dtype=int64)

# %%
data_without_null.describe()
# Out:
#               YEAR          JAN          FEB          MAR          APR
# count  4090.000000  4090.000000  4090.000000  4090.000000  4090.000000  \
# mean   1958.321271    18.818484    21.644792    27.252494    42.714548
# std      33.148944    33.521719    35.762010    46.829179    67.264863
# min    1901.000000     0.000000     0.000000     0.000000     0.000000
# 25%    1930.000000     0.600000     0.600000     1.000000     3.000000
# 50%    1959.000000     5.900000     6.600000     7.800000    15.500000
# 75%    1987.000000    21.950000    26.600000    31.100000    49.375000
# max    2015.000000   583.700000   403.500000   605.600000   595.100000
#
#                MAY          JUN          JUL          AUG          SEP
# count  4090.000000  4090.000000  4090.000000  4090.000000  4090.000000  \
# mean     84.868044   228.928020   346.496968   289.897506   197.003056
# std     122.556801   233.535693   269.352685   187.702293   135.266708
# ...

# %%
data_without_null.shape
# Out:
# (4090, 19)

# %% [markdown]
# # Data Visualization

# %%
import matplotlib.pyplot as plt

sorted_data = data_without_null.sort_values(by='ANNUAL', ascending=False)

plt.figure(figsize=(10, 10)) 
plt.barh(sorted_data['SUBDIVISION'], sorted_data['ANNUAL'])
plt.xlabel('Annual Rainfall (in mm)')
plt.ylabel('SUBDIVISION of States')
plt.title('Annual Rainfall by Subdivision (Sorted)')
plt.grid(axis='x')
plt.show()

# %%
plt.figure(figsize=(15,8))
data_without_null.groupby("YEAR").sum()['ANNUAL'].plot(kind="line",color='r',marker='*')
plt.xlabel("YEARS",size=12)
plt.ylabel("RAINFALL IN MM",size=12)
plt.grid(axis="both")
plt.title("Rainfall over Years")
plt.show()

# %%
data_without_null[['YEAR','JAN','FEB','MAR','APR','MAY','JUN','JUL','AUG','SEP','OCT','NOV','DEC']].groupby("YEAR").sum().plot(kind="line",figsize=(18,8))
plt.xlabel("Year",size=13)
plt.ylabel("Rainfall in MM",size=13)
plt.title("Year V/S Rainfall in each month",size=20)
plt.show()

# %%
data_without_null[['YEAR','Jan-Feb','Mar-May','Jun-Sep','Oct-Dec']].groupby("YEAR").sum().plot(kind="line",figsize=(18,8))
plt.xlabel("Year",size=13)
plt.ylabel("Rainfall in MM",size=13)
plt.title("Year V/S Rainfall in range of months",size=20)
plt.show()

# %%
data_without_null[['SUBDIVISION','JAN','FEB','MAR','APR','MAY','JUN','JUL','AUG','SEP','OCT','NOV','DEC']].groupby("SUBDIVISION").sum().plot(kind="barh",stacked=True,figsize=(25,15))
plt.xlabel("Rainfall in MM",size=15)
plt.ylabel("Sub-division",size=15)
plt.title("Sub-division V/S Rainfall in each month",size=20)
plt.grid(axis="x",linestyle="-")
plt.show()

# %%
data_without_null[['SUBDIVISION','Jan-Feb','Mar-May','Jun-Sep','Oct-Dec']].groupby("SUBDIVISION").sum().plot(kind="barh",stacked=True,figsize=(25,15))
plt.xlabel("Rainfall in MM",size=15)
plt.ylabel("Sub-division",size=15)
plt.title("Sub-division V/S Rainfall in each month",size=20)
plt.grid(axis="x",linestyle="-")
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(15,7))
sns.heatmap(data_without_null[['JAN','FEB','MAR','APR','MAY','JUN','JUL','AUG','SEP','OCT','NOV','DEC','ANNUAL']].corr(),annot=True)
plt.show()
