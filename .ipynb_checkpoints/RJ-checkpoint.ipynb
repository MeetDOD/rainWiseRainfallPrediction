# %%
import pandas as pd

data = pd.read_csv('data_without_null')
data.head()
# Out:
#                  SUBDIVISION  YEAR   JAN    FEB   MAR    APR    MAY    JUN
# 0  ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1  29.2    2.3  528.8  517.5  \
# 1  ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8  12.2    0.0  446.1  537.1
# 2  ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0   0.0    1.0  235.1  479.9
# 3  ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7   0.0  202.4  304.5  495.1
# 4  ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0   3.3   26.9  279.5  628.7
#
#      JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  Jan-Feb  Mar-May
# 0  365.1  481.1  332.6  388.5  558.2   33.6  3373.2    136.3    560.3  \
# 1  228.9  753.7  666.2  197.2  359.0  160.5  3520.7    159.8    458.3
# 2  728.4  326.7  339.0  181.2  284.4  225.0  2957.4    156.7    236.1
# 3  502.0  160.1  820.4  222.2  308.7   40.1  3079.6     24.1    506.9
# 4  368.7  330.5  297.0  260.7   25.4  344.7  2566.7      1.3    309.7
#
#    Jun-Sep  Oct-Dec
# 0   1696.3    980.3
# 1   2185.9    716.7
# 2   1874.0    690.6
# 3   1977.6    571.0
# 4   1624.9    630.8

# %%
RJ = data.loc[(data['SUBDIVISION'] == 'EAST RAJASTHAN') | (data['SUBDIVISION'] == 'WEST RAJASTHAN')]
RJ.head()
# Out:
#          SUBDIVISION  YEAR  JAN  FEB   MAR  APR   MAY   JUN    JUL   AUG
# 1804  WEST RAJASTHAN  1901  6.7  0.0   1.1  0.0   6.1   3.0   79.0  59.2  \
# 1805  WEST RAJASTHAN  1902  0.0  0.0   0.0  0.5   4.0  49.1   27.0  71.3
# 1806  WEST RAJASTHAN  1903  1.7  1.3   5.5  0.0   4.2   2.7  154.8  87.1
# 1807  WEST RAJASTHAN  1904  3.8  2.9  16.3  0.7  11.4  14.6   39.8  45.6
# 1808  WEST RAJASTHAN  1905  6.3  4.8   0.7  1.3   0.3   4.9   30.1   0.6
#
#        SEP  OCT  NOV  DEC  ANNUAL  Jan-Feb  Mar-May  Jun-Sep  Oct-Dec
# 1804   1.0  2.1  0.0  0.6   158.9      6.7      7.2    142.2      2.7
# 1805  41.8  1.8  0.0  0.0   195.6      0.0      4.5    189.2      1.8
# 1806  49.3  0.1  0.0  0.5   307.0      3.0      9.7    293.8      0.5
# 1807  21.4  1.4  2.9  7.1   167.9      6.6     28.5    121.4     11.4
# 1808  64.5  0.0  0.0  0.9   114.4     11.0      2.4    100.1      0.9

# %%
import matplotlib.pyplot as plt

RJ[['JAN','FEB','MAR','APR','MAY','JUN','JUL','AUG','SEP','OCT','NOV','DEC']].mean().plot(kind="bar",width=0.7,linewidth=3)
plt.title("RAJASTHAN Rainfall V/S Months",size=15)
plt.xlabel("Months",size=15)
plt.ylabel("Rainfall in MM",size=15)
plt.grid(axis="both",linestyle="-")
plt.show()

# %%
RJ.groupby("YEAR").sum()['ANNUAL'].plot(color='r',marker="o",linestyle='-',linewidth=2,figsize=(12,8))
plt.title("RAJASTHAN Annual Rainfall from year 1901 to 2015",size=17)
plt.xlabel("Year",size=15)
plt.ylabel("Rainfall in MM",size=15)
plt.grid()
plt.show()

# %%
group = data.groupby('SUBDIVISION')[['YEAR', 'JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']]
data = pd.concat([group.get_group('EAST RAJASTHAN'), group.get_group('WEST RAJASTHAN')])
data.head()
# Out:
#       YEAR   JAN  FEB   MAR  APR   MAY   JUN    JUL    AUG    SEP   OCT  NOV
# 1919  1901  21.6  8.9   2.9  0.7   5.0  15.0  164.8  175.6    7.5   9.8  0.0  \
# 1920  1902   4.1  0.7   0.0  1.8   9.9  34.6  247.6  116.7  145.6  14.4  0.0
# 1921  1903   1.9  0.7   1.3  0.1  12.9  15.6  238.2  229.1  168.5  17.8  0.0
# 1922  1904   4.3  5.5  21.7  0.2  27.5  49.9  289.7  223.5   50.2   1.5  5.8
# 1923  1905   4.1  8.8   3.2  1.6   2.0  14.4  130.5   30.9   83.8   0.0  0.0
#
#        DEC
# 1919   0.8
# 1920   2.8
# 1921   0.0
# 1922  14.7
# 1923   0.6

# %%
df = data.melt(['YEAR']).reset_index()
df.head()
# Out:
#    index  YEAR variable  value
# 0      0  1901      JAN   21.6
# 1      1  1902      JAN    4.1
# 2      2  1903      JAN    1.9
# 3      3  1904      JAN    4.3
# 4      4  1905      JAN    4.1

# %%
df = df[['YEAR','variable','value']].reset_index().sort_values(by=['YEAR','index'])
df.head()
# Out:
#      index  YEAR variable  value
# 0        0  1901      JAN   21.6
# 115    115  1901      JAN    6.7
# 230    230  1901      FEB    8.9
# 345    345  1901      FEB    0.0
# 460    460  1901      MAR    2.9

# %%
df.YEAR.unique()
# Out:
# array([1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911,
#        1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922,
#        1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933,
#        1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944,
#        1945, 1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955,
#        1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966,
#        1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977,
#        1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988,
#        1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999,
#        2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010,
#        2011, 2012, 2013, 2014, 2015], dtype=int64)

# %%
df.columns=['Index','Year','Month','Avg Rainfall']
df.head()
# Out:
#      Index  Year Month  Avg Rainfall
# 0        0  1901   JAN          21.6
# 115    115  1901   JAN           6.7
# 230    230  1901   FEB           8.9
# 345    345  1901   FEB           0.0
# 460    460  1901   MAR           2.9

# %%
monthMap = {'JAN':1,'FEB':2,'MAR':3,'APR':4,'MAY':5,'JUN':6,'JUL':7,'AUG':8,'SEP':9,'OCT':10,'NOV':11,'DEC':12}
df['Month'] = df['Month'].map(monthMap)
df.head(10)
# Out:
#       Index  Year  Month  Avg Rainfall
# 0         0  1901      1          21.6
# 115     115  1901      1           6.7
# 230     230  1901      2           8.9
# 345     345  1901      2           0.0
# 460     460  1901      3           2.9
# 575     575  1901      3           1.1
# 690     690  1901      4           0.7
# 805     805  1901      4           0.0
# 920     920  1901      5           5.0
# 1035   1035  1901      5           6.1

# %%
df.drop(columns="Index",inplace=True)

# %%
df.head()
# Out:
#      Year  Month  Avg Rainfall
# 0    1901      1          21.6
# 115  1901      1           6.7
# 230  1901      2           8.9
# 345  1901      2           0.0
# 460  1901      3           2.9

# %%
df.groupby("Year").sum().plot()
plt.show()

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(df['Avg Rainfall'])
plt.subplot(2,2,2)
sns.boxplot(df['Avg Rainfall'])
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_16896\4153292416.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Avg Rainfall'])
# <Axes: ylabel='Avg Rainfall'>

# %%
percentile25 = df['Avg Rainfall'].quantile(0.25)
percentile75 = df['Avg Rainfall'].quantile(0.75)
iqr = percentile75 - percentile25

# %%
upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr

df[df['Avg Rainfall'] > upper_limit]
df[df['Avg Rainfall'] < lower_limit]
# Out:
# Empty DataFrame
# Columns: [Year, Month, Avg Rainfall]
# Index: []

# %%
new_df = df[df['Avg Rainfall'] < upper_limit]
new_df.shape
# Out:
# (2372, 3)

# %%
plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(df['Avg Rainfall'])
plt.subplot(2,2,2)
sns.boxplot(df['Avg Rainfall'])

plt.subplot(2,2,3)
sns.distplot(new_df['Avg Rainfall'])
plt.subplot(2,2,4)
sns.boxplot(new_df['Avg Rainfall'])
plt.show()
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_16896\118003576.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Avg Rainfall'])
# C:\Users\Acer\AppData\Local\Temp\ipykernel_16896\118003576.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['Avg Rainfall'])

# %%
percentile25 = new_df['Avg Rainfall'].quantile(0.25)
percentile75 = new_df['Avg Rainfall'].quantile(0.75)
iqr = percentile75 - percentile25

upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr

new_df[new_df['Avg Rainfall'] > upper_limit]
new_df[new_df['Avg Rainfall'] < lower_limit]

new_df2 = new_df[new_df['Avg Rainfall'] < upper_limit]
new_df2.shape
# Out:
# (2072, 3)

# %%
plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(new_df['Avg Rainfall'])
plt.subplot(2,2,2)
sns.boxplot(new_df['Avg Rainfall'])

plt.subplot(2,2,3)
sns.distplot(new_df2['Avg Rainfall'])
plt.subplot(2,2,4)
sns.boxplot(new_df2['Avg Rainfall'])
plt.show()
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_16896\2775748692.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df['Avg Rainfall'])
# C:\Users\Acer\AppData\Local\Temp\ipykernel_16896\2775748692.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df2['Avg Rainfall'])

# %%
percentile25 = new_df2['Avg Rainfall'].quantile(0.25)
percentile75 = new_df2['Avg Rainfall'].quantile(0.75)
iqr = percentile75 - percentile25

upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr

new_df2[new_df2['Avg Rainfall'] > upper_limit]
new_df2[new_df2['Avg Rainfall'] < lower_limit]

new_df3 = new_df2[new_df2['Avg Rainfall'] < upper_limit]
new_df3.shape
# Out:
# (1864, 3)

# %%
plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(new_df2['Avg Rainfall'])
plt.subplot(2,2,2)
sns.boxplot(new_df2['Avg Rainfall'])

plt.subplot(2,2,3)
sns.distplot(new_df3['Avg Rainfall'])
plt.subplot(2,2,4)
sns.boxplot(new_df3['Avg Rainfall'])
plt.show()
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_16896\1473949475.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df2['Avg Rainfall'])
# C:\Users\Acer\AppData\Local\Temp\ipykernel_16896\1473949475.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df3['Avg Rainfall'])

# %%
percentile25 = new_df3['Avg Rainfall'].quantile(0.25)
percentile75 = new_df3['Avg Rainfall'].quantile(0.75)
iqr = percentile75 - percentile25

upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr

new_df3[new_df3['Avg Rainfall'] > upper_limit]
new_df3[new_df3['Avg Rainfall'] < lower_limit]

new_df4 = new_df3[new_df3['Avg Rainfall'] < upper_limit]
new_df4.shape
# Out:
# (1734, 3)

# %%
percentile25 = new_df4['Avg Rainfall'].quantile(0.25)
percentile75 = new_df4['Avg Rainfall'].quantile(0.75)
iqr = percentile75 - percentile25

upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr

new_df4[new_df4['Avg Rainfall'] > upper_limit]
new_df4[new_df4['Avg Rainfall'] < lower_limit]

new_df5 = new_df4[new_df4['Avg Rainfall'] < upper_limit]
new_df5.shape
# Out:
# (1651, 3)

# %%
percentile25 = new_df5['Avg Rainfall'].quantile(0.25)
percentile75 = new_df5['Avg Rainfall'].quantile(0.75)
iqr = percentile75 - percentile25

upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr

new_df5[new_df5['Avg Rainfall'] > upper_limit]
new_df5[new_df5['Avg Rainfall'] < lower_limit]

new_df6 = new_df5[new_df5['Avg Rainfall'] < upper_limit]
new_df6.shape
# Out:
# (1587, 3)

# %%
percentile25 = new_df6['Avg Rainfall'].quantile(0.25)
percentile75 = new_df6['Avg Rainfall'].quantile(0.75)
iqr = percentile75 - percentile25

upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr

new_df6[new_df6['Avg Rainfall'] > upper_limit]
new_df6[new_df6['Avg Rainfall'] < lower_limit]

new_df7 = new_df6[new_df6['Avg Rainfall'] < upper_limit]
new_df7.shape
# Out:
# (1537, 3)

# %%
plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(new_df6['Avg Rainfall'])
plt.subplot(2,2,2)
sns.boxplot(new_df6['Avg Rainfall'])

plt.subplot(2,2,3)
sns.distplot(new_df7['Avg Rainfall'])
plt.subplot(2,2,4)
sns.boxplot(new_df7['Avg Rainfall'])
plt.show()
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_16896\2544749326.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df6['Avg Rainfall'])
# C:\Users\Acer\AppData\Local\Temp\ipykernel_16896\2544749326.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df7['Avg Rainfall'])

# %%
percentile25 = new_df7['Avg Rainfall'].quantile(0.25)
percentile75 = new_df7['Avg Rainfall'].quantile(0.75)
iqr = percentile75 - percentile25

upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr

new_df7[new_df7['Avg Rainfall'] > upper_limit]
new_df7[new_df7['Avg Rainfall'] < lower_limit]

new_df8 = new_df7[new_df7['Avg Rainfall'] < upper_limit]
new_df8.shape
# Out:
# (1499, 3)

# %%
percentile25 = new_df8['Avg Rainfall'].quantile(0.25)
percentile75 = new_df8['Avg Rainfall'].quantile(0.75)
iqr = percentile75 - percentile25

upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr

new_df8[new_df8['Avg Rainfall'] > upper_limit]
new_df8[new_df8['Avg Rainfall'] < lower_limit]

new_df9 = new_df8[new_df8['Avg Rainfall'] < upper_limit]
new_df9.shape
# Out:
# (1474, 3)

# %%
percentile25 = new_df9['Avg Rainfall'].quantile(0.25)
percentile75 = new_df9['Avg Rainfall'].quantile(0.75)
iqr = percentile75 - percentile25

upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr

new_df9[new_df9['Avg Rainfall'] > upper_limit]
new_df9[new_df9['Avg Rainfall'] < lower_limit]

new_df10 = new_df9[new_df9['Avg Rainfall'] < upper_limit]
new_df10.shape
# Out:
# (1428, 3)

# %%
plt.figure(figsize=(16,8))
plt.subplot(2,2,1)
sns.distplot(new_df9['Avg Rainfall'])
plt.subplot(2,2,2)
sns.boxplot(new_df9['Avg Rainfall'])

plt.subplot(2,2,3)
sns.distplot(new_df10['Avg Rainfall'])
plt.subplot(2,2,4)
sns.boxplot(new_df10['Avg Rainfall'])
plt.show()
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_16896\2939395209.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df9['Avg Rainfall'])
# C:\Users\Acer\AppData\Local\Temp\ipykernel_16896\2939395209.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df10['Avg Rainfall'])

# %%
import numpy as np
from sklearn.model_selection import train_test_split

X = np.asanyarray(new_df10[['Year','Month']]).astype('int')
Y = np.asanyarray(new_df10['Avg Rainfall']).astype('int')

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

print(X.shape)
print(Y.shape)
# Out:
# (1428, 2)
# (1428,)

# %%
new_df10.head(10)
# Out:
#       Year  Month  Avg Rainfall
# 345   1901      2           0.0
# 460   1901      3           2.9
# 575   1901      3           1.1
# 690   1901      4           0.7
# 805   1901      4           0.0
# 920   1901      5           5.0
# 1265  1901      6           3.0
# 1955  1901      9           1.0
# 2185  1901     10           2.1
# 2300  1901     11           0.0

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import r2_score

knn_model = KNeighborsRegressor(n_neighbors=5) 
knn_model.fit(X_train, Y_train)

y_train_predict = knn_model.predict(X_train)
y_test_predict = knn_model.predict(X_test)

predicted = knn_model.predict([[1901, 3]])

train_r2_score = r2_score(Y_train, y_train_predict)

test_r2_score = r2_score(Y_test, y_test_predict)

print("R-squared score on training data:", train_r2_score)
print("R-squared score on test data:", test_r2_score)
print("Predicted value for [1901, 1]:", predicted)
# Out:
# R-squared score on training data: 0.3326743713872038
# R-squared score on test data: -0.15884331582795985
# Predicted value for [1901, 1]: [0.6]

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score

random_forest_model = RandomForestRegressor(n_estimators=50, random_state=45)
random_forest_model.fit(X_train, Y_train)

y_train_predict = random_forest_model.predict(X_train)
y_test_predict = random_forest_model.predict(X_test)

predicted = random_forest_model.predict([[1901, 3]])

train_r2_score = r2_score(Y_train, y_train_predict)

test_r2_score = r2_score(Y_test, y_test_predict)

print("R-squared score on training data:", train_r2_score)
print("R-squared score on test data:", test_r2_score)
print("Predicted value ", predicted)
# Out:
# R-squared score on training data: 0.7455762241514428
# R-squared score on test data: -0.15048460623378523
# Predicted value  [1.34966667]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

linear_model = LinearRegression()
linear_model.fit(X_train, Y_train)

y_train_predict = linear_model.predict(X_train)
y_test_predict = linear_model.predict(X_test)

predicted = linear_model.predict([[1901, 3]])

train_r2_score = r2_score(Y_train, y_train_predict)
test_r2_score = r2_score(Y_test, y_test_predict)

print("R-squared score on training data:", train_r2_score)
print("R-squared score on test data:", test_r2_score)
print("Predicted value:", predicted)
# Out:
# R-squared score on training data: 0.009097864673581424
# R-squared score on test data: 0.015233698738881474
# Predicted value: [1.17043685]

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score

decision_tree_model = DecisionTreeRegressor(random_state=45)
decision_tree_model.fit(X_train, Y_train)

y_train_predict = decision_tree_model.predict(X_train)
y_test_predict = decision_tree_model.predict(X_test)

predicted = decision_tree_model.predict([[1901, 10]])

train_r2_score = r2_score(Y_train, y_train_predict)

test_r2_score = r2_score(Y_test, y_test_predict)

print("R-squared score on training data:", train_r2_score)
print("R-squared score on test data:", test_r2_score)
print("Predicted value:", predicted[0])
# Out:
# R-squared score on training data: 0.826737496389249
# R-squared score on test data: -0.49331915176494046
# Predicted value: 2.0

# %%
import pickle

pickle.dump(decision_tree_model,open('rj_decesion_tree_model.pkl','wb'))

# %%
pickel_model = pickle.load(open('rj_decesion_tree_model.pkl','rb'))
pickel_model.predict([[1901, 10]])
# Out:
# array([2.])
